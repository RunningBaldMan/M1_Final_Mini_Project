# %% [markdown]
# Core Components
#     Product
#         Attributes: name, price, stock
#         Represents an individual item in the store
#     Store
#         Holds a list of Product objects
#         Displays the current inventory
#         Includes a method to look up a product by name
#     ShoppingCart
#         Stores items and quantities selected by the user
#         Includes methods to:
#             Add a product
#             Remove a product
#             View cart contents
#             Get total cost
#             Checkout (update stock, clear cart)
#     Basic Requirements
#         The store should start with at least five products
#         The user should be able to add and remove products from the cart, but not exceed available stock
#         The user should be able to view their cart and see a total price
#         When checking out, the system should update the stock levels and clear the cart
#     Stretch Goals (Optional)
#         Try adding any of the following if you want to go further:
#         Apply tax or discounts at checkout
#         Store purchase history
#         Gracefully handle out-of-stock items
#         Add a Customer class and support multiple users
#         Load or save product data from a CSV file
#         Think ahead: how could you turn this into a GUI or web app?
#     Reflection Questions
#         Once you've tried building it, take a moment to reflect:
#             What does this remind you of from real life?
#             Which parts of your code could be reused in another program?
#             What are some next steps you could take to build this out further?
#
# Starter Code
#     Here's a simple Product class to help you begin:
#
#         class Product:
#             def __init__(self, name, price, stock):
#                 self.name = name
#                 self.price = price
#                 self.stock = stock
#     And some basic structure for the ShoppingCart class:
#
#         class ShoppingCart:
#                 def __init__(self):
#                     self.items = {}  # {product: quantity}
#                 def add_product(self, product, quantity):
#                     pass
#                 def remove_product(self, product, quantity):
#                     pass
#                 def view_cart(self):
#                     pass
#                 def get_total(self):
#                     pass
#                 def checkout(self):
#                     pass
#
# Take your time with it, build it step-by-step, and have fun with the process. This is a great opportunity to apply everything you've been learning in a hands-on, creative way.
#
# Did you like this lesson?
#
# imgimg

# %%
class Product:
    def __init__(self, item, price, quantity):
        self.item = item
        # may or may not need location
        # self.location = location
        self.price = price
        self.quantity = quantity

# location (freezer, produce, dairy, meat, dry goods, beverages)
class Store(Product):
    def __init__(self, item, location, price, quantity):
        super().__init__(item, location, price, quantity)

class Freezer(Product):
    def __init__(self, item, price, quantity):
        super().__init__(item, price, quantity)

class Produce(Product):
    def __init__(self, item, price, quantity):
        super().__init__(item, price, quantity)

class Dairy(Product):
    def __init__(self, item, price, quantity):
        super().__init__(item, price, quantity)

class Meat(Product):
    def __init__(self, item, price, quantity):
        super().__init__(item, price, quantity)

class Dry_Goods(Product):
    def __init__(self, item, price, quantity):
        super().__init__(item, price, quantity)
 
class Beverages(Product):
    def __init__(self, item, price, quantity):
        super().__init__(item, price, quantity)



class ShoppingCart:
    def __init__(self):
        self.items = {prduct: [pice, quantity]}

    def add_product(self, product, price, quantity):
        pass

    def remove_product(self, product, price, quantity):
        pass

    def view_cart(self):
        pass

    def get_total(self):
        pass

# Should there be a {product: price}?
# Need to factor quantity in somehow. 
    def checkout(self):
        pass


# Search for product in store
print("What do are you looking for? Please enter one of the items: ")
item = input()



# Product freezer, produce, dairy, meat, dry goods, beverages
Product = [
    Freezer("Pizza", "$5.95", 1),
    Freezer("Ice Cream", "$7.99", 1), 
    Produce("Apple", "$1.29", 1), 
    Produce("Orange", "$1.05", 1), 
    Produce("Lettuce", "$0.50", 1), 
    Produce("Tomato", "$3.79", 1),
    Dairy("Milk", "$3.75", 1), 
    Dairy("Ice Cream", "$6.99", 1),
    Meat("Ground Beef", "$5.00", 1),
    Meat("Pork Chops", "$7.50", 1),
    Dry_Goods("Rice", "$0.99", 1),
    Dry_Goods("Pasta", "$1.50", 1),
    Beverages("Sprite", "$8.00", 1), 
    Beverages("Water", "$0.75", 1)
]

def find_product_by_food(list_of_products, search_food):
# Where the food can be found
    for product in list_of_products:
        if search_food in product:
            return product

found_product = list_of_products, (Poduct, item)
print(f"The ", {items}, "are located in the ", {found_product}, "section.")
# Out:
# What do are you looking for? Please enter one of the items:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 92
#      89         if search_food in product:
#      90             return product
# ---> 92 found_product = list_of_products, (Poduct, item)
#      93 print(f"The ", {items}, "are located in the ", {found_product}, "section.")
#
# NameError: name 'list_of_products' is not defined
